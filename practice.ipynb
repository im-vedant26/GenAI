# %%
# web based loader.
from langchain_community.document_loaders.web.base import WebBaseLoader
import bs4
loader = WebBaseLoader(web_path="https://en.wikipedia.org/wiki/Tata_Consultancy_Services")

webdata = loader.load()
print(webdata[0])
# Out:
# C:\Users\vedant\AppData\Local\Temp\ipykernel_4428\3567836113.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders.web.base import WebBaseLoader
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # web based loader.
# ----> 2 from langchain_community.document_loaders.web.base import WebBaseLoader
#       3 import bs4
#       4 loader = WebBaseLoader(web_path="https://en.wikipedia.org/wiki/Tata_Consultancy_Services")
#       5 webdata = loader.load()
#
# ModuleNotFoundError: No module named 'langchain_community.document_loaders.web'
